# %% [markdown]
# <a href="https://colab.research.google.com/github/brenoromeroaraujo/datasettempoonline/blob/main/Transfusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics

import pandas as pd

url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/transfusion.data"

# %%
# Carregar base de dados
# DataFrame
dataset = pd.read_csv(url, header=None)

columns = len(dataset.columns)

y = dataset[0] # extrai a primeira coluna, que é o label
X = dataset.loc[:,1:columns-1]

# %%
#Dividir treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None, stratify=y) # 80% treino e 20% teste

# %%
# Treinamendo da Árvore de Decisão
#model = tree.DecisionTreeClassifier(criterion="entropy")
model = tree.DecisionTreeClassifier(criterion="entropy")
model = model.fit(X_train, y_train)

# %%
# Predição e Resultados

# Fazer previsões e calcular a acurácia
result = model.predict(X_test)
acc = metrics.accuracy_score(result, y_test)
show = round(acc * 100)
print("{}%".format(show))
print(list(result))
print(list(y_test))
# Out:
# 64%
# ...

# %%
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.5025669642857142, 0.9722222222222222, 'x[0] <= 6.5\nentropy = 0.791\nsamples = 598\nvalue = [142, 456]'),
#  Text(0.2591517857142857, 0.9166666666666666, 'x[2] <= 1125.0\nentropy = 0.953\nsamples = 292\nvalue = [109, 183]'),
#  Text(0.380859375, 0.9444444444444444, 'True  '),
#  Text(0.07991071428571428, 0.8611111111111112, 'x[3] <= 44.5\nentropy = 0.834\nsamples = 136\nvalue = [36, 100]'),
#  Text(0.07276785714285715, 0.8055555555555556, 'x[3] <= 2.5\nentropy = 0.851\nsamples = 130\nvalue = [36, 94]'),
#  Text(0.04285714285714286, 0.75, 'x[1] <= 1.5\nentropy = 0.605\nsamples = 27\nvalue = [4, 23]'),
#  Text(0.03571428571428571, 0.6944444444444444, 'entropy = 0.634\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.05, 0.6944444444444444, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10267857142857142, 0.75, 'x[3] <= 12.0\nentropy = 0.894\nsamples = 103\nvalue = [32.0, 71.0]'),
# ...
